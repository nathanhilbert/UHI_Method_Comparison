# %%
import os.path as op

thefiles = {'CC_allstations': 'climatecentral/allstations.csv', 
            'CC_daymet': 'climatecentral/climatecentraldaymet.csv',
           'CC_prism': 'climatecentral/climatecentralprism.csv',
           'Dabbage_allstations': 'Dabbage/dabbage_allstations.csv',
           'Dabbage_daymet': 'Dabbage/dabbage_daymet.csv',
           'Dabbage_prism': 'Dabbage/dabbage_prism.csv',
           'Dabbage_results': 'litresults/DabbageResults.csv',
           'CC_results': 'litresults/cc_results.csv'}

#urbanname,uhi

#placename, uhimin, uhimax, uhiavg

import csv

thedata = {}
for k, finname in thefiles.iteritems():
    thedata[k] = {}
    with open(finname, 'r') as fin:
        reader  = csv.DictReader(fin)
        for row in reader:
            thedata[k][row['placename']] = row

# %%
import numpy as np

from bokeh.io import gridplot, output_notebook, show, output_file
from bokeh.models import CustomJS,TapTool, ColumnDataSource
from bokeh.plotting import figure
output_notebook()

def create_scatter(dataset1, dataset2, measure, title="",
                  x_label="", y_label=""):
    dataset = []
    for d1placename, d1row in dataset1.iteritems():
        for d2placename, d2row in dataset2.iteritems():
            if d1placename.strip().lower().find(d2placename.strip().lower()) != -1 \
                    and d1row.get(measure, False) and d2row.get(measure, False):
                dataset.append([d1row[measure], d2row[measure]])
    
    npds = np.array(dataset).T
      
    temps = figure(width=700, plot_height=700, title=title, 
               tools="pan,wheel_zoom,box_zoom,reset,tap",
                  x_axis_label=x_label,
                  y_axis_label=y_label)
#     ixs = v1.index.intersection(v2.index)
#     newv1 = v1[ixs]
#     newv2 = v2[ixs]

    source = ColumnDataSource(data=dict(
    x=npds[0],
    y=npds[1]
    ))


    temps.circle('x', 'y', color='blue', size=5, source=source, alpha=1)
    
    show(temps)
                                
create_scatter(thedata['CC_allstations'], thedata['CC_results'], 'uhitavg', 'CC AllStations x CC Lit Results',
              'CC AllStations', 'CC Lit Results')
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5a0e67cb-7727-4c8d-92ec-baf31c3d6e9d">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="plotdiv" id="2c99122e-39a5-40ed-84e1-d8114cdcddef"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("2c99122e-39a5-40ed-84e1-d8114cdcddef");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '2c99122e-39a5-40ed-84e1-d8114cdcddef' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"a3c9bd12-750e-46ee-9eca-378723b00b80":{"roots":{"references":[{"attributes":{},"id":"c8ee33ac-5cae-459c-845f-bfe1a11c44ba","type":"BasicTickFormatter"},{"attributes":{"axis_label":"CC Lit Results","formatter":{"id":"c8ee33ac-5cae-459c-845f-bfe1a11c44ba","type":"BasicTickFormatter"},"plot":{"id":"34d36239-c670-48ff-ad99-f0d7d7a01b12","subtype":"Figure","type":"Plot"},"ticker":{"id":"e77b84f8-6e7a-4eab-b2bf-9f04dd959b93","type":"BasicTicker"}},"id":"4d18b4e4-9b9b-4b98-8df4-4782c3c9935c","type":"LinearAxis"},{"attributes":{"plot":{"id":"34d36239-c670-48ff-ad99-f0d7d7a01b12","subtype":"Figure","type":"Plot"}},"id":"112341e0-9c03-4d9d-a72c-3b63073d26d4","type":"PanTool"},{"attributes":{},"id":"a5d78270-9984-46d0-b019-c4736774b8cc","type":"BasicTicker"},{"attributes":{"plot":{"id":"34d36239-c670-48ff-ad99-f0d7d7a01b12","subtype":"Figure","type":"Plot"}},"id":"13cd15bf-613d-4493-bddf-9e5f630f9422","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"8a3150d4-7196-4ee2-8db4-447cf897d16c","type":"DataRange1d"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"112341e0-9c03-4d9d-a72c-3b63073d26d4","type":"PanTool"},{"id":"13cd15bf-613d-4493-bddf-9e5f630f9422","type":"WheelZoomTool"},{"id":"d9f901c9-0777-4e40-9771-d29b0c803fdf","type":"BoxZoomTool"},{"id":"d8a24cd9-169f-41e3-9916-a91a792f0da8","type":"ResetTool"},{"id":"ae31a0b8-77fd-4666-8477-e543597a2105","type":"TapTool"}]},"id":"84ef555f-a1f0-4f05-82ae-01f6447656c0","type":"Toolbar"},{"attributes":{"plot":{"id":"34d36239-c670-48ff-ad99-f0d7d7a01b12","subtype":"Figure","type":"Plot"},"ticker":{"id":"a5d78270-9984-46d0-b019-c4736774b8cc","type":"BasicTicker"}},"id":"203fa9ac-0861-41ab-a1ab-b4770dfaee24","type":"Grid"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"059f84a5-595d-4c80-8ccf-a09a9f0dcdc9","type":"BoxAnnotation"},{"attributes":{"axis_label":"CC AllStations","formatter":{"id":"a23bc4ff-296f-45ba-8588-f721ffa08ab1","type":"BasicTickFormatter"},"plot":{"id":"34d36239-c670-48ff-ad99-f0d7d7a01b12","subtype":"Figure","type":"Plot"},"ticker":{"id":"a5d78270-9984-46d0-b019-c4736774b8cc","type":"BasicTicker"}},"id":"d06ca274-1bb4-4ca0-8da1-db0b94def356","type":"LinearAxis"},{"attributes":{"overlay":{"id":"059f84a5-595d-4c80-8ccf-a09a9f0dcdc9","type":"BoxAnnotation"},"plot":{"id":"34d36239-c670-48ff-ad99-f0d7d7a01b12","subtype":"Figure","type":"Plot"}},"id":"d9f901c9-0777-4e40-9771-d29b0c803fdf","type":"BoxZoomTool"},{"attributes":{},"id":"79fc8fa8-0314-4f0f-b57f-e890223be469","type":"ToolEvents"},{"attributes":{"callback":null,"plot":{"id":"34d36239-c670-48ff-ad99-f0d7d7a01b12","subtype":"Figure","type":"Plot"}},"id":"ae31a0b8-77fd-4666-8477-e543597a2105","type":"TapTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"b0da3862-e71b-45d4-aa8c-96e8e5adfe9d","type":"Circle"},{"attributes":{},"id":"a23bc4ff-296f-45ba-8588-f721ffa08ab1","type":"BasicTickFormatter"},{"attributes":{},"id":"e77b84f8-6e7a-4eab-b2bf-9f04dd959b93","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"34d36239-c670-48ff-ad99-f0d7d7a01b12","subtype":"Figure","type":"Plot"},"ticker":{"id":"e77b84f8-6e7a-4eab-b2bf-9f04dd959b93","type":"BasicTicker"}},"id":"42e74119-db80-4849-aed7-85a111c2bf16","type":"Grid"},{"attributes":{"callback":null},"id":"8e804dad-9b9e-4d02-b8e1-3f842a567637","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.9011669823749755","-0.066226849015325231","0.67729886302889353","1.3668096334745257","3.0007662579540479","-0. ...

# %%
create_scatter(thedata['CC_prism'], thedata['CC_results'], 'uhitavg', 'CC Prism x CC Lit Results',
              'CC Prism', 'CC Lit Results')
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="3ce60f93-e94c-4f01-98f0-fb9d082ff81b"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3ce60f93-e94c-4f01-98f0-fb9d082ff81b");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3ce60f93-e94c-4f01-98f0-fb9d082ff81b' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"792ca4c5-5cc8-49b5-990e-633ea8f67482":{"roots":{"references":[{"attributes":{"plot":{"id":"365362d4-475f-49d8-9f91-7873c793110f","subtype":"Figure","type":"Plot"},"ticker":{"id":"a2eff053-8b24-41a7-9f22-1d5b2640805b","type":"BasicTicker"}},"id":"8508d1fa-3e63-47a6-8a7b-e977ba7cf730","type":"Grid"},{"attributes":{"dimension":1,"plot":{"id":"365362d4-475f-49d8-9f91-7873c793110f","subtype":"Figure","type":"Plot"},"ticker":{"id":"5b9d0446-e212-4d67-a685-e90b6c048205","type":"BasicTicker"}},"id":"fc3f9d10-c79d-4750-a8e6-5caaccf2a2e6","type":"Grid"},{"attributes":{"below":[{"id":"dfe55f44-3415-480e-bac8-d558c421f455","type":"LinearAxis"}],"left":[{"id":"7f6ce7dd-045b-4fc5-b99b-68673c9a9626","type":"LinearAxis"}],"plot_height":700,"plot_width":700,"renderers":[{"id":"dfe55f44-3415-480e-bac8-d558c421f455","type":"LinearAxis"},{"id":"8508d1fa-3e63-47a6-8a7b-e977ba7cf730","type":"Grid"},{"id":"7f6ce7dd-045b-4fc5-b99b-68673c9a9626","type":"LinearAxis"},{"id":"fc3f9d10-c79d-4750-a8e6-5caaccf2a2e6","type":"Grid"},{"id":"9f71afa1-e1f6-4d9e-a829-9482c639abaa","type":"BoxAnnotation"},{"id":"27426ebe-62ad-4ad3-a697-95de91b0a505","type":"GlyphRenderer"}],"title":{"id":"b546a872-732e-43d3-9d17-702295b9d934","type":"Title"},"tool_events":{"id":"fb9eec6c-f026-4588-95b5-6b6133203a9c","type":"ToolEvents"},"toolbar":{"id":"ea251a37-96fa-40fa-9131-1c973d2d6f23","type":"Toolbar"},"x_range":{"id":"ceeff40e-abe1-4482-b708-7eedb563a1f2","type":"DataRange1d"},"y_range":{"id":"36424d6e-1085-4e2a-98fd-c877e10e8e08","type":"DataRange1d"}},"id":"365362d4-475f-49d8-9f91-7873c793110f","subtype":"Figure","type":"Plot"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"5a7c83a1-4918-4d8e-8b37-8d73f0409add","type":"PanTool"},{"id":"fc00d8b0-c87d-4470-918c-2311bcc9c0e5","type":"WheelZoomTool"},{"id":"e637c422-4935-47ff-bb85-1a4f20506811","type":"BoxZoomTool"},{"id":"af13acac-63ed-4435-9436-ff53e7a5e88a","type":"ResetTool"},{"id":"162ed64f-a466-4648-85c0-d66993de69b7","type":"TapTool"}]},"id":"ea251a37-96fa-40fa-9131-1c973d2d6f23","type":"Toolbar"},{"attributes":{"plot":{"id":"365362d4-475f-49d8-9f91-7873c793110f","subtype":"Figure","type":"Plot"}},"id":"af13acac-63ed-4435-9436-ff53e7a5e88a","type":"ResetTool"},{"attributes":{"overlay":{"id":"9f71afa1-e1f6-4d9e-a829-9482c639abaa","type":"BoxAnnotation"},"plot":{"id":"365362d4-475f-49d8-9f91-7873c793110f","subtype":"Figure","type":"Plot"}},"id":"e637c422-4935-47ff-bb85-1a4f20506811","type":"BoxZoomTool"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"f90d3176-312b-4c84-83ee-f07aba79234c","type":"Circle"},{"attributes":{"callback":null},"id":"36424d6e-1085-4e2a-98fd-c877e10e8e08","type":"DataRange1d"},{"attributes":{"plot":{"id":"365362d4-475f-49d8-9f91-7873c793110f","subtype":"Figure","type":"Plot"}},"id":"fc00d8b0-c87d-4470-918c-2311bcc9c0e5","type":"WheelZoomTool"},{"attributes":{"callback":null},"id":"ceeff40e-abe1-4482-b708-7eedb563a1f2","type":"DataRange1d"},{"attributes":{},"id":"5b9d0446-e212-4d67-a685-e90b6c048205","type":"BasicTicker"},{"attributes":{"callback":null,"plot":{"id":"365362d4-475f-49d8-9f91-7873c793110f","subtype":"Figure","type":"Plot"}},"id":"162ed64f-a466-4648-85c0-d66993de69b7","type":"TapTool"},{"attributes":{},"id":"a2eff053-8b24-41a7-9f22-1d5b2640805b","type":"BasicTicker"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["0.06607686404575475","2.733773508166852","0.2162665967469657","0.43166015877029906","1.3649946749653594","0.824848831924264","0.17879551998933962","-1.382066086383258","3.0019468857433047","0.4725398033702213","0.607434434829468","0.2545337462561257","0.7318728243159391","0.5648361523227656","0.13246599726564412","0.1977040746882004","0.4442468612729229","0.5873636709898413","1.0000467495788463","-1.7390320180981824","1.4602783597596485","0.08462370371174188","0.6795023053 ...

# %%
create_scatter(thedata['CC_daymet'], thedata['CC_results'], 'uhitavg', 'CC Daymet x CC Lit Results',
              'CC Daymet', 'CC Lit Results')
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="96e4bfaf-3c48-43ed-a687-0203ae8c8bcf"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("96e4bfaf-3c48-43ed-a687-0203ae8c8bcf");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '96e4bfaf-3c48-43ed-a687-0203ae8c8bcf' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"f7bb93bb-b917-41cc-87b7-3de0aab433c8":{"roots":{"references":[{"attributes":{"plot":{"id":"45b36710-0fcb-4570-aaea-e818daaaa3a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"123b2c37-90df-4efd-965f-6832a503d58f","type":"BasicTicker"}},"id":"b0ffaf4e-7a34-4a25-9441-b1954d57d90c","type":"Grid"},{"attributes":{},"id":"ca30d5f1-337d-4cdc-97f4-af672f6f1c11","type":"BasicTickFormatter"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"05b47d23-95b8-4614-9b09-c0efc0d30238","type":"Circle"},{"attributes":{"axis_label":"CC Lit Results","formatter":{"id":"ca30d5f1-337d-4cdc-97f4-af672f6f1c11","type":"BasicTickFormatter"},"plot":{"id":"45b36710-0fcb-4570-aaea-e818daaaa3a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"e1ba532d-baf8-4f4a-a49a-d10d0d787308","type":"BasicTicker"}},"id":"0c089192-cb48-413e-abe5-8d74d61e141e","type":"LinearAxis"},{"attributes":{"overlay":{"id":"60c3455a-0ce5-47f3-8295-cdc30bceb698","type":"BoxAnnotation"},"plot":{"id":"45b36710-0fcb-4570-aaea-e818daaaa3a3","subtype":"Figure","type":"Plot"}},"id":"55ef93df-3ce3-4c34-8083-06b63fa2f561","type":"BoxZoomTool"},{"attributes":{},"id":"c67e5b4e-51d9-4a56-8fb5-35fe41583ad0","type":"ToolEvents"},{"attributes":{},"id":"e1ba532d-baf8-4f4a-a49a-d10d0d787308","type":"BasicTicker"},{"attributes":{"dimension":1,"plot":{"id":"45b36710-0fcb-4570-aaea-e818daaaa3a3","subtype":"Figure","type":"Plot"},"ticker":{"id":"e1ba532d-baf8-4f4a-a49a-d10d0d787308","type":"BasicTicker"}},"id":"be3f4fce-06a0-4773-844f-345314c99cc1","type":"Grid"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c9312cd0-8b89-4b1f-8119-ee47d916d785","type":"PanTool"},{"id":"f70271c2-eb7b-4365-9e1c-d1b89fb8693b","type":"WheelZoomTool"},{"id":"55ef93df-3ce3-4c34-8083-06b63fa2f561","type":"BoxZoomTool"},{"id":"7124cece-a7fe-4cff-8b57-80aa7fa45f2b","type":"ResetTool"},{"id":"b1ae1b15-c941-49d5-96a2-6c0de66a7fdb","type":"TapTool"}]},"id":"0e1291c8-d9e3-496e-94e4-725f7a47cdb0","type":"Toolbar"},{"attributes":{"plot":{"id":"45b36710-0fcb-4570-aaea-e818daaaa3a3","subtype":"Figure","type":"Plot"}},"id":"f70271c2-eb7b-4365-9e1c-d1b89fb8693b","type":"WheelZoomTool"},{"attributes":{"plot":null,"text":"CC Daymet x CC Lit Results"},"id":"4f79a64a-2720-4d4f-83f8-e1d8591dda6e","type":"Title"},{"attributes":{},"id":"123b2c37-90df-4efd-965f-6832a503d58f","type":"BasicTicker"},{"attributes":{"callback":null},"id":"3945a384-4205-4745-8fcd-a01cdd67e97e","type":"DataRange1d"},{"attributes":{"below":[{"id":"6457fa84-395f-4ce7-b21a-c9a0acd2e8c9","type":"LinearAxis"}],"left":[{"id":"0c089192-cb48-413e-abe5-8d74d61e141e","type":"LinearAxis"}],"plot_height":700,"plot_width":700,"renderers":[{"id":"6457fa84-395f-4ce7-b21a-c9a0acd2e8c9","type":"LinearAxis"},{"id":"b0ffaf4e-7a34-4a25-9441-b1954d57d90c","type":"Grid"},{"id":"0c089192-cb48-413e-abe5-8d74d61e141e","type":"LinearAxis"},{"id":"be3f4fce-06a0-4773-844f-345314c99cc1","type":"Grid"},{"id":"60c3455a-0ce5-47f3-8295-cdc30bceb698","type":"BoxAnnotation"},{"id":"9a6331d4-42de-4be5-a335-a251f6c5c66e","type":"GlyphRenderer"}],"title":{"id":"4f79a64a-2720-4d4f-83f8-e1d8591dda6e","type":"Title"},"tool_events":{"id":"c67e5b4e-51d9-4a56-8fb5-35fe41583ad0","type":"ToolEvents"},"toolbar":{"id":"0e1291c8-d9e3-496e-94e4-725f7a47cdb0","type":"Toolbar"},"x_range":{"id":"3945a384-4205-4745-8fcd-a01cdd67e97e","type":"DataRange1d"},"y_range":{"id":"5ccd30f5-e691-4096-8a7f-a1d0fe572a8b","type":"DataRange1d"}},"id":"45b36710-0fcb-4570-aaea-e818daaaa3a3","subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"45b36710-0fcb-4570-aaea-e818daaaa3a3","subtype":"Figure","type":"Plot"}},"id":"c9312cd0-8b89-4b1f-8119-ee47d916d785","type":"PanTool"},{"attributes":{},"id":"ff90b675-9935-4405-812c-aeff5fa1b19e","type":"BasicTickFormatter"},{"attributes":{"callback":null,"plot":{"id":"45b36710-0fcb-4570-aaea-e818daaaa3a3" ...

# %%
create_scatter(thedata['Dabbage_allstations'], thedata['Dabbage_results'], 'uhitmin', 'Dabbage AllStations x Dabbage Results',
              'Dabbage AllStations', 'Dabbage Lit Results')
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="297762ab-d32d-47cc-b931-c56f4e03b2dc"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("297762ab-d32d-47cc-b931-c56f4e03b2dc");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '297762ab-d32d-47cc-b931-c56f4e03b2dc' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5d997eb2-18b8-468a-9dec-cc2d172f0cc6":{"roots":{"references":[{"attributes":{"plot":{"id":"a095f95e-026b-4c34-b4dd-bb77c38bf272","subtype":"Figure","type":"Plot"}},"id":"6a3e0684-2756-4fe2-b3ac-5cf7d7033666","type":"PanTool"},{"attributes":{},"id":"5b657ca9-fc0c-4548-9299-486a05c754b5","type":"ToolEvents"},{"attributes":{"plot":{"id":"a095f95e-026b-4c34-b4dd-bb77c38bf272","subtype":"Figure","type":"Plot"}},"id":"6e7fa51c-9714-41bd-bc8a-7511a5ca1923","type":"WheelZoomTool"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"1825bd37-7623-43e1-a92f-87575eee14b7","type":"Circle"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"8bb6bc6c-0674-47ac-b507-4b5303a08f1d","type":"Circle"},{"attributes":{},"id":"c05e93c0-6aa5-48ef-aa0f-dcaf2fddeadf","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["1.1778492178315076","0.72360142122369098","1.993278179188394","2.2440184484612757","2.4153196979729046","0.6412959013333932","2.4505322924702213","4.7664696418329342","2.4347769309206839","0.89690404958176373","2.4432574610934523","5.6297667660024331","-2.3978756007655875","1.2890053785510318","0.1044791343792113","1.547626922685204","-1.7328794394011879","0.52117763169090381","2.0049157333128846","1.547626922685204","4.0160680578830892","1.2708300734710676","1.2507490199708258","1.3058763532912678","1.7392873764597141","1.2147703716026612","-0.85845088108526113","1.2229864326031077","0.9720078374748482","0.52282949438769322","0.68748960991081276","1.748942040378175","1.858507113571406","2.7526418619089412","1.0401944381980428","1.9845129259949772","2.8044808269405337","1.3287131178072116","0.015978057904177945","3.9798339607172295","-0.12722162819187588","1.5300000979207269","2.7822426915506497"],"y":["0.51","0.17","0.6","0.6","0.29","0.12","0.89","1.25","0.52","0.07","0.25","0.36","1.44","0.24","-0.18","-0.19","-0.98","0.69","0","-0.33","1.13","0.42","0.22","0.23","0.06","0.82","0.02","0.15","0.64","0.88","0.22","0.35","0.14","0.29","0.12","0.77","0.55","0.28","0.1","0.89","0.22","0.12","0.47"]}},"id":"f8c12389-2234-40e7-b351-db243708bc98","type":"ColumnDataSource"},{"attributes":{"plot":{"id":"a095f95e-026b-4c34-b4dd-bb77c38bf272","subtype":"Figure","type":"Plot"}},"id":"1f1a4da3-2cc0-4309-a01f-faa0898326b6","type":"ResetTool"},{"attributes":{"data_source":{"id":"f8c12389-2234-40e7-b351-db243708bc98","type":"ColumnDataSource"},"glyph":{"id":"8bb6bc6c-0674-47ac-b507-4b5303a08f1d","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"1825bd37-7623-43e1-a92f-87575eee14b7","type":"Circle"},"selection_glyph":null},"id":"e24968d4-1867-4546-81c9-9195ee3a98e7","type":"GlyphRenderer"},{"attributes":{"below":[{"id":"e62be6f1-cce8-4a0d-8787-cb937c43da59","type":"LinearAxis"}],"left":[{"id":"ea5b489f-58e5-4dd9-99ed-b6c994d07bc9","type":"LinearAxis"}],"plot_height":700,"plot_width":700,"renderers":[{"id":"e62be6f1-cce8-4a0d-8787-cb937c43da59","type":"LinearAxis"},{"id":"f601ddda-2694-4a97-91d1-dce4646c7581","type":"Grid"},{"id":"ea5b489f-58e5-4dd9-99ed-b6c994d07bc9","type":"LinearAxis"},{"id":"bb9b1f3c-d1b5-4397-b781-2f40c27ef696","type":"Grid"},{"id":"8215fb68-e957-4d91-a9e8-2824fcb8cd6f","type":"BoxAnnotation"},{"id":"e24968d4-1867-4546-81c9-9195ee3a98e7","type":"GlyphRenderer"}],"title":{"id":"c62ad7a2-7a30-4b73-a273-36b3b33d0fa9","type":"Title"},"tool_events":{"id":"5b657ca9-fc0c-4548-9299-486a05c754b5","type":"ToolEvents"},"toolbar":{"id":"877d5ffe-1b25-403e-8776-3e8cb9b73cbc","type":"Toolbar"},"x_range":{"id":"ac3f9396-376b-4364-ab47-4db0cdba99b9","type":"DataRange1d"},"y_range":{"id":"bfd5be8f-100b-4a1e-be5f-c8a715b0b10f","type":"DataRange1d"}},"id":"a095f95e-026b-4c34-b4dd-bb77c38bf272","subtype ...

# %%
create_scatter(thedata['Dabbage_prism'], thedata['Dabbage_results'], 'uhitmin', 'Dabbage Prism x Dabbage Results',
              'Dabbage Prism', 'Dabbage Lit Results')
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="215a55f7-9ce8-4863-b287-edaff4455790"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("215a55f7-9ce8-4863-b287-edaff4455790");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '215a55f7-9ce8-4863-b287-edaff4455790' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"5950aa3f-8758-4b1f-acc1-6cc28f481ed3":{"roots":{"references":[{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"9513cc33-1c9a-4382-87f8-107aa647e064","type":"PanTool"},{"id":"a56e8b62-d452-41d7-b00f-82313099ce9f","type":"WheelZoomTool"},{"id":"dc54a47c-08ac-494a-ba57-82d1c337a09a","type":"BoxZoomTool"},{"id":"c1f354b8-c630-4c76-a72d-2f703f058fbd","type":"ResetTool"},{"id":"924cae5a-824f-44cd-bcfc-0289caf4c92c","type":"TapTool"}]},"id":"20fda883-5811-47af-9f27-54258cb2bd1f","type":"Toolbar"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"92c6c7d3-b62f-4130-b212-6a577d12a0b1","type":"Circle"},{"attributes":{},"id":"ea0e0044-cc20-42d9-abbf-77e29165130e","type":"ToolEvents"},{"attributes":{"callback":null},"id":"9e88fc62-f322-45b5-9ba2-e0bdeae97777","type":"DataRange1d"},{"attributes":{"plot":{"id":"fb5126f1-1b24-412a-b0bc-fef2315db71f","subtype":"Figure","type":"Plot"},"ticker":{"id":"be0e68e8-f3c2-4f39-9a7e-ffe9ce39a786","type":"BasicTicker"}},"id":"9006fad7-106e-439f-9366-63a7dee74fd4","type":"Grid"},{"attributes":{},"id":"cb04025b-88be-40b3-9d2c-8bc1b3cc5862","type":"BasicTickFormatter"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"f1808f12-bfbc-4498-bba6-9c504a2ea7d8","type":"Circle"},{"attributes":{"overlay":{"id":"2c979775-9046-494a-942c-e16a505ad4dd","type":"BoxAnnotation"},"plot":{"id":"fb5126f1-1b24-412a-b0bc-fef2315db71f","subtype":"Figure","type":"Plot"}},"id":"dc54a47c-08ac-494a-ba57-82d1c337a09a","type":"BoxZoomTool"},{"attributes":{"callback":null},"id":"3fb08843-c2b0-424e-83ee-8dfda6f18e00","type":"DataRange1d"},{"attributes":{"data_source":{"id":"6afd48e9-92ca-45f3-8af5-efc2c2f5e3ec","type":"ColumnDataSource"},"glyph":{"id":"92c6c7d3-b62f-4130-b212-6a577d12a0b1","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"f1808f12-bfbc-4498-bba6-9c504a2ea7d8","type":"Circle"},"selection_glyph":null},"id":"34dd582f-1258-44cc-80c5-1aa8e7b254dc","type":"GlyphRenderer"},{"attributes":{"callback":null,"plot":{"id":"fb5126f1-1b24-412a-b0bc-fef2315db71f","subtype":"Figure","type":"Plot"}},"id":"924cae5a-824f-44cd-bcfc-0289caf4c92c","type":"TapTool"},{"attributes":{"axis_label":"Dabbage Lit Results","formatter":{"id":"cb04025b-88be-40b3-9d2c-8bc1b3cc5862","type":"BasicTickFormatter"},"plot":{"id":"fb5126f1-1b24-412a-b0bc-fef2315db71f","subtype":"Figure","type":"Plot"},"ticker":{"id":"0af37a92-b7a3-4a58-b22b-7cd2773669ac","type":"BasicTicker"}},"id":"a033274b-33fa-447d-a200-75fd7dfe9b12","type":"LinearAxis"},{"attributes":{"callback":null,"column_names":["y","x"],"data":{"x":["0.6109578371922453","1.7546756843961973","0.8524604433426362","0.6267489560949571","0.38724020941665316","0.35249844507275085","0.1648481846708112","0.6240206907588579","1.592752433224124","10.850782922832636","0.549995609497735","0.5037378217825044","0.1970249142933298","0.11739355613514846","-9.147854703241013","0.09031644632900537","0.3489404366862985","0.7778466507410009","0.32350776781330737","0.7186552361177618","0.6882689985949995","1.592752433224124","0.33124363304103","0.4582704690453383","-0.22462671833585368","1.8593869286750486","0.7694104294037523","0.5156808065351726","0.7186552361177618","1.0066309346292925","0.3976864959926161","nan","0.6239626381429524","0.1560528027987793","-0.33099724541857967","0.7285453733335494","0.6326433926587143","0.813700742179833","1.1245531898322128","0.7473170221446708","0.3878998312634394","0.5037378217825044","5.580709688449687"],"y":["0.51","0.17","0.6","0.6","0.29","0.12","0.89","1.25","0.52","0.07","0.25","0.36","1.44","0.24","-0.18","-0.19","-0.98","0.69","0","-0.33","1.13","0.42","0.22","0.23","0.06","0.82","0.02","0.15","0.64","0.88","0.22","0.35","0 ...

# %%
create_scatter(thedata['Dabbage_daymet'], thedata['Dabbage_results'], 'uhitmin', 'Dabbage DaymeD x Dabbage Results',
              'Dabbage Daymet', 'Dabbage Lit Results')
# Out:
#     <div class="bk-root">
#         <div class="plotdiv" id="6d861aaa-9f2b-4bab-bc94-f834216fa519"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined") {
#       window._bokeh_onload_callbacks = [];
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("6d861aaa-9f2b-4bab-bc94-f834216fa519");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '6d861aaa-9f2b-4bab-bc94-f834216fa519' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         Bokeh.$(function() {
#             var docs_json = {"c1342f30-e1c7-434b-8d96-52d195adb94f":{"roots":{"references":[{"attributes":{"callback":null,"plot":{"id":"6ed3d793-6a57-4fa2-90a8-c4197d5c7fe0","subtype":"Figure","type":"Plot"}},"id":"eff6c493-c8f5-4553-a3cf-dc1bedc51f11","type":"TapTool"},{"attributes":{"plot":{"id":"6ed3d793-6a57-4fa2-90a8-c4197d5c7fe0","subtype":"Figure","type":"Plot"}},"id":"62e27cac-1ba7-4160-b74e-9e6f12a2c842","type":"WheelZoomTool"},{"attributes":{"plot":{"id":"6ed3d793-6a57-4fa2-90a8-c4197d5c7fe0","subtype":"Figure","type":"Plot"},"ticker":{"id":"199da1e4-4a5a-49e6-8944-d3a4cb4cbea0","type":"BasicTicker"}},"id":"897978c3-c4d4-4243-8a0b-426b07a154c3","type":"Grid"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"9c89e8fc-8145-49ad-b7e7-7203347ca54e","type":"Circle"},{"attributes":{"plot":{"id":"6ed3d793-6a57-4fa2-90a8-c4197d5c7fe0","subtype":"Figure","type":"Plot"}},"id":"9799b0b2-7c48-4c63-bf13-47c4aa10ced0","type":"ResetTool"},{"attributes":{"data_source":{"id":"cf251903-4598-4b36-aac1-ae707bcd057a","type":"ColumnDataSource"},"glyph":{"id":"9c89e8fc-8145-49ad-b7e7-7203347ca54e","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"ddfef6e5-ecc4-489e-be81-759713fd5acd","type":"Circle"},"selection_glyph":null},"id":"e57fa815-2504-4e7f-923a-04b24ce55019","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"89bed70f-7e12-4a34-bc11-96c1180e7e39","type":"DataRange1d"},{"attributes":{"dimension":1,"plot":{"id":"6ed3d793-6a57-4fa2-90a8-c4197d5c7fe0","subtype":"Figure","type":"Plot"},"ticker":{"id":"7402c578-2a9d-447e-9436-dfce0e5fe0bf","type":"BasicTicker"}},"id":"54eba46f-7f71-45b0-b1b9-73ee4337bcbd","type":"Grid"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":5},"x":{"field":"x"},"y":{"field":"y"}},"id":"ddfef6e5-ecc4-489e-be81-759713fd5acd","type":"Circle"},{"attributes":{"axis_label":"Dabbage Lit Results","formatter":{"id":"07275c18-1f9a-441e-aca2-63c589ac34df","type":"BasicTickFormatter"},"plot":{"id":"6ed3d793-6a57-4fa2-90a8-c4197d5c7fe0","subtype":"Figure","type":"Plot"},"ticker":{"id":"7402c578-2a9d-447e-9436-dfce0e5fe0bf","type":"BasicTicker"}},"id":"b6b95e41-4655-41f7-b2d2-7c2846cfe5b3","type":"LinearAxis"},{"attributes":{"active_drag":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"342b491f-6f02-4a04-a278-fa9a4450c752","type":"PanTool"},{"id":"62e27cac-1ba7-4160-b74e-9e6f12a2c842","type":"WheelZoomTool"},{"id":"791f447e-089c-403e-937d-d34f1ff6cec5","type":"BoxZoomTool"},{"id":"9799b0b2-7c48-4c63-bf13-47c4aa10ced0","type":"ResetTool"},{"id":"eff6c493-c8f5-4553-a3cf-dc1bedc51f11","type":"TapTool"}]},"id":"779cd46b-6d35-4468-855b-ed6819f2eea1","type":"Toolbar"},{"attributes":{"axis_label":"Dabbage Daymet","formatter":{"id":"526069ac-08bc-41fc-88aa-ca979ffc1967","type":"BasicTickFormatter"},"plot":{"id":"6ed3d793-6a57-4fa2-90a8-c4197d5c7fe0","subtype":"Figure","type":"Plot"},"ticker":{"id":"199da1e4-4a5a-49e6-8944-d3a4cb4cbea0","type":"BasicTicker"}},"id":"88892365-545b-4144-b21d-ed55f6566b4c","type":"LinearAxis"},{"attributes":{},"id":"7402c578-2a9d-447e-9436-dfce0e5fe0bf","type":"BasicTicker"},{"attributes":{"callback":null},"id":"1a079206-2c92-4137-b49d-3a7be775606e","type":"DataRange1d"},{"attributes":{},"id":"199da1e4-4a5a-49e6-8944-d3a4cb4cbea0","type":"BasicTicker"},{"attributes":{"overlay":{"id":"07193bb2-8a2f-4951-a8c6-8c2dfa91fefc","type":"BoxAnnotation"},"plot":{"id":"6ed3d793-6a57-4fa2-90a8-c4197d5c7fe0","subtype":"Figure","type":"Plot"}},"id":"791f447e-089c-403e-937d-d34f1ff6cec5","type":"BoxZoomTool"},{"attributes":{},"id":"526069ac-08bc-41fc-88aa-ca979ffc1967","type":"BasicTickFormatter"},{"attributes":{"plot":null,"text":"Dabbage DaymeD x Dabbage Results"},"id":"7be33a96-2a19-437b-a6a5-a32525f447f0","type":"Title"},{"attributes":{"callback":null ...
